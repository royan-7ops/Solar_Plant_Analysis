# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c417977e-2c60-4b04-a05f-2ce46f6de473" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c417977e-2c60-4b04-a05f-2ce46f6de473">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('Plant_1_Generation_Data.csv')
df.head()
# Out:
#           DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0  15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 1  15-05-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0
# 2  15-05-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0
# 3  15-05-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0
# 4  15-05-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0
#
#    DAILY_YIELD  TOTAL_YIELD
# 0          0.0    6259559.0
# 1          0.0    6183645.0
# 2          0.0    6987759.0
# 3          0.0    7602960.0
# 4          0.0    7158964.0

# %%
import zipfile

with zipfile.ZipFile("Plant_1_Generation_Data.csv.zip", 'r') as zip_ref:
    zip_ref.extractall()  # extracts the CSV in the same folder

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'Plant_1_Generation_Data.csv.zip',
#  'Plant_1_Generation_Data.csv',
#  'sample_data']

# %%
import pandas as pd
df = pd.read_csv("Plant_1_Generation_Data.csv")
df = pd.read_csv("Plant_1_Generation_Data.csv.zip")
df.head()
# Out:
#           DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0  15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 1  15-05-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0
# 2  15-05-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0
# 3  15-05-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0
# 4  15-05-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0
#
#    DAILY_YIELD  TOTAL_YIELD
# 0          0.0    6259559.0
# 1          0.0    6183645.0
# 2          0.0    6987759.0
# 3          0.0    7602960.0
# 4          0.0    7158964.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['TOTAL_YIELD'].plot(kind='hist', bins=20, title='TOTAL_YIELD')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# ...

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("/content/Plant_1_Generation_Data.csv")

# Display first 5 rows
df.head()
# Out:
#           DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0  15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 1  15-05-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0
# 2  15-05-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0
# 3  15-05-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0
# 4  15-05-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0
#
#    DAILY_YIELD  TOTAL_YIELD
# 0          0.0    6259559.0
# 1          0.0    6183645.0
# 2          0.0    6987759.0
# 3          0.0    7602960.0
# 4          0.0    7158964.0

# %%
with open("Plant_1_Generation_Data.csv", 'r') as f:
    lines = f.readlines()
print(len(lines))  # How many lines your CSV actually has
# Out:
# 68779

# %%
import pandas as pd

# Step 1: Try reading normally
try:
    df = pd.read_csv("Plant_1_Generation_Data.csv")
except:
    # fallback: try different encoding
    df = pd.read_csv("Plant_1_Generation_Data.csv", encoding='utf-16')

# Step 2: Check number of rows
print("Total rows loaded:", df.shape[0])

# Step 3: Peek at first 5 rows
print(df.head())
# Out:
# Total rows loaded: 68778
#           DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0  15-05-2020 00:00   4135001  1BY6WEcLGh8j5v7       0.0       0.0
# 1  15-05-2020 00:00   4135001  1IF53ai7Xc0U56Y       0.0       0.0
# 2  15-05-2020 00:00   4135001  3PZuoBAID5Wc2HD       0.0       0.0
# 3  15-05-2020 00:00   4135001  7JYdWkrLSPkdwr4       0.0       0.0
# 4  15-05-2020 00:00   4135001  McdE0feGgRqW7Ca       0.0       0.0
#
#    DAILY_YIELD  TOTAL_YIELD
# 0          0.0    6259559.0
# 1          0.0    6183645.0
# 2          0.0    6987759.0
# 3          0.0    7602960.0
# 4          0.0    7158964.0

# %%
print(df.shape)   # should show (68778, 7)
# Out:
# (68778, 7)

# %%
df.tail()
# Out:
#               DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 68773  17-06-2020 23:45   4135001  uHbuxQJl8lW7ozc       0.0       0.0
# 68774  17-06-2020 23:45   4135001  wCURE6d3bPkepu2       0.0       0.0
# 68775  17-06-2020 23:45   4135001  z9Y9gH1T5YWrNuG       0.0       0.0
# 68776  17-06-2020 23:45   4135001  zBIq5rxdHJRwDNY       0.0       0.0
# 68777  17-06-2020 23:45   4135001  zVJPv84UY57bAof       0.0       0.0
#
#        DAILY_YIELD  TOTAL_YIELD
# 68773     5967.000    7287002.0
# 68774     5147.625    7028601.0
# 68775     5819.000    7251204.0
# 68776     5817.000    6583369.0
# 68777     5910.000    7363272.0
